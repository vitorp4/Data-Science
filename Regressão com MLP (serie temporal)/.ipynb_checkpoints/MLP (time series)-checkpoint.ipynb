# %%
import numpy as np
import pandas as pd
import tensorflow
import keras
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('centrais.csv')
df
# Out:
#                      timestamp  YAMBUKWF  YSWF1  WAUBRAWF  SALTCRK1  PORTWF  \
# 0       2018-01-01T00:00+10:00       2.3    0.0    69.950       NaN    76.0
# 1       2018-01-01T00:05+10:00       2.5    0.0    73.795       NaN    70.6
# 2       2018-01-01T00:10+10:00       2.7    0.0    66.958       NaN    66.8
# 3       2018-01-01T00:15+10:00       2.7    0.0    65.716       NaN    61.3
# 4       2018-01-01T00:20+10:00       3.3    0.0    58.506       NaN    60.7
# ...                        ...       ...    ...       ...       ...     ...
# 105115  2018-12-31T23:35+10:00       NaN    0.0    50.106      1.60    -0.4
# 105116  2018-12-31T23:40+10:00       NaN    0.0    48.241      1.79    -0.4
# 105117  2018-12-31T23:45+10:00      -0.2    0.0    46.897      1.39    -0.4
# 105118  2018-12-31T23:50+10:00      -0.2    0.0    43.039      1.04    -0.4
# 105119  2018-12-31T23:55+10:00      -0.2    0.0    39.976      0.84    -0.4
#
# ...
